# %% [markdown]
# ## 1. Shallow neural networks

# %% [markdown]
# - Flexible enough to describe arbitrarily complex input/output mappings
# - Can have as many inputs as we want
# - Can have as many outputs as we want

# %% [markdown]
# **1D Linear Regression**
#
# $y = f[x, w]$
#
# $  = w_{0}+w_{1}x$

# %% [markdown]
# **shallow network**
#
# $y = f[x, \phi]$
#
# $= \phi_{0} + \phi_{1}a[θ_{10} + θ_{11}x] + \phi_{2}a[θ_{20} + θ_{21}x] + \phi_{3}a[θ_{30} + θ_{31}x]$

# %% [markdown]
# where $a$ is an activation function
#
# <img src="img/pic3.png" width=250 height=250 />

# %% [markdown]
# <img src="img/pic4.png" width=600 height=600 />

# %% [markdown]
# ### Universal approximation theorem

# %% [markdown]
# -  The number of hidden units in a shallow network is a measure of **the network capacity**.

# %% [markdown]
# - With ReLU activation functions, the output of a network with D hidden units has at most D joints and so is a piecewise linear function with at most D + 1 linear regions.
#
# - As we add more hidden units, the model can approximate more complex functions.

# %% [markdown]
# <img src="img/pic5.png" width=600 height=600 />

# %% [markdown]
# >> a formal proof that, with enough hidden units, a shallow neural network can describe any continuous function on a compact subset of $R^{D}$ to arbitrary precision

# %% [markdown]
# ### Arbitrary inputs, hidden units, outputs

# %% [markdown]
# <img src="img/pic6.png" width=400 height=400 />

# %% [markdown]
# #### How many parameters does this model have?

# %% [markdown]
# <img src="img/pic7.png" width=300 height=300 />

# %% [markdown]
# ______________________________

# %% [markdown]
# **What happens if we feed one neural network into another neural network?**

# %% [markdown]
# ## 2. Deep Neural Networks

# %% [markdown]
# ### Two-layer network

# %% [markdown]
# <img src="img/pic9.png" width=500 height=500 />

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# - $K$ layers = depth of network
# - $𝐷_{𝑘}$ hidden units per layer = width of network
#
# - These are called hyperparameters – chosen before training the network
# - Can try retraining with different hyperparameters – hyperparameter optimization or hyperparameter search

# %% [markdown]
# ### Shallow vs. deep networks

# %% [markdown]
# The best results are created by deep networks with many layers.
#
# 50-1000 layers for most applications
#
# Best results in
# - Computer vision
# - Natural language processing
# - Graph neural networks
# - Generative models
# - Reinforcement learning

# %% [markdown]
# **1. Ability to approximate different functions?**
#
# Both obey the universal approximation theorem.

# %% [markdown]
# **2. Number of linear regions per parameter**
# - Deep networks create many more regions per parameters
# - But there are dependencies between them

# %% [markdown]
# <img src="img/pic10.png" width=500 height=500 />

# %% [markdown]
# **3. Depth efficiency**
#
# - There are some functions that require a shallow network with exponentially more hidden units than a deep network to achieve an equivalent approximation
#
# - This is known as the depth efficiency of deep networks
#
# - But do the real-world functions we want to approximate have this property?  Unknown.

# %% [markdown]
# **4. Large structured networks**
#
# - Think about images as input – might be 1M pixels
# - Fully connected works but not practical
# - Answer is to have weights that only operate locally, and share across image
# - This leads to convolutional networks Gradually integrate information from across the image – needs multiple layers

# %% [markdown]
# **5. Fitting and generalization**
#
# - Fitting of deep models seems to be easier up to about 20 layers
# - Then needs various tricks to train deeper networks, so (in vanilla form), fitting becomes harder
# - Generalization is good in deep networks. Why?

# %% [markdown]
# <img src="img/pic11.png" width=400 height=400 />
